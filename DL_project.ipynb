# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# #Data Preprocessing

# %%
df=pd.read_csv('train.csv')

# %%
df.head()
# Out:
#        Id Prediction  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# 0  100000          s       138.470                       51.655        97.827
# 1  100001          b       160.937                       68.768       103.235
# 2  100002          b      -999.000                      162.172       125.953
# 3  100003          b       143.905                       81.417        80.943
# 4  100004          b       175.864                       16.915       134.805
#
#    DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0    27.980                  0.91           124.711                2.666
# 1    48.146               -999.00          -999.000             -999.000
# 2    35.635               -999.00          -999.000             -999.000
# 3     0.414               -999.00          -999.000             -999.000
# 4    16.405               -999.00          -999.000             -999.000
#
#    DER_deltar_tau_lep  ...  PRI_met_phi  PRI_met_sumet  PRI_jet_num  \
# 0               3.064  ...       -0.277        258.733            2
# 1               3.473  ...       -1.916        164.546            1
# 2               3.148  ...       -2.186        260.414            1
# 3               3.310  ...        0.060         86.062            0
# 4               3.891  ...       -0.871         53.131            0
#
#    PRI_jet_leading_pt  PRI_jet_leading_eta  PRI_jet_leading_phi  \
# 0              67.435                2.150                0.444
# 1              46.226                0.725                1.158
# 2              44.251                2.053               -2.028
# 3            -999.000             -999.000             -999.000
# 4            -999.000             -999.000             -999.000
#
#    PRI_jet_subleading_pt  PRI_jet_subleading_eta  PRI_jet_subleading_phi  \
# 0                 46.062                    1.24                  -2.475
# 1               -999.000                 -999.00                -999.000
# 2               -999.000                 -999.00                -999.000
# 3               -999.000                 -999.00                -999.000
# 4               -999.000                 -999.00                -999.000
#
#    PRI_jet_all_pt
# 0         113.497
# 1          46.226
# 2          44.251
# 3           0.000
# 4           0.000
#
# [5 rows x 32 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Id                             0
# Prediction                     0
# DER_mass_MMC                   0
# DER_mass_transverse_met_lep    0
# DER_mass_vis                   0
# DER_pt_h                       0
# DER_deltaeta_jet_jet           0
# DER_mass_jet_jet               0
# DER_prodeta_jet_jet            0
# DER_deltar_tau_lep             0
# DER_pt_tot                     0
# DER_sum_pt                     0
# DER_pt_ratio_lep_tau           0
# DER_met_phi_centrality         0
# DER_lep_eta_centrality         0
# PRI_tau_pt                     0
# PRI_tau_eta                    0
# PRI_tau_phi                    0
# PRI_lep_pt                     0
# PRI_lep_eta                    0
# PRI_lep_phi                    0
# PRI_met                        0
# PRI_met_phi                    0
# PRI_met_sumet                  0
# PRI_jet_num                    0
# PRI_jet_leading_pt             0
# PRI_jet_leading_eta            0
# PRI_jet_leading_phi            0
# PRI_jet_subleading_pt          0
# PRI_jet_subleading_eta         0
# PRI_jet_subleading_phi         0
# PRI_jet_all_pt                 0
# dtype: int64

# %%
df.drop(columns=['Id'],inplace=True)

# %%
df.head()
# Out:
#   Prediction  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# 0          s       138.470                       51.655        97.827
# 1          b       160.937                       68.768       103.235
# 2          b      -999.000                      162.172       125.953
# 3          b       143.905                       81.417        80.943
# 4          b       175.864                       16.915       134.805
#
#    DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0    27.980                  0.91           124.711                2.666
# 1    48.146               -999.00          -999.000             -999.000
# 2    35.635               -999.00          -999.000             -999.000
# 3     0.414               -999.00          -999.000             -999.000
# 4    16.405               -999.00          -999.000             -999.000
#
#    DER_deltar_tau_lep  DER_pt_tot  ...  PRI_met_phi  PRI_met_sumet  \
# 0               3.064      41.928  ...       -0.277        258.733
# 1               3.473       2.078  ...       -1.916        164.546
# 2               3.148       9.336  ...       -2.186        260.414
# 3               3.310       0.414  ...        0.060         86.062
# 4               3.891      16.405  ...       -0.871         53.131
#
#    PRI_jet_num  PRI_jet_leading_pt  PRI_jet_leading_eta  PRI_jet_leading_phi  \
# 0            2              67.435                2.150                0.444
# 1            1              46.226                0.725                1.158
# 2            1              44.251                2.053               -2.028
# 3            0            -999.000             -999.000             -999.000
# 4            0            -999.000             -999.000             -999.000
#
#    PRI_jet_subleading_pt  PRI_jet_subleading_eta  PRI_jet_subleading_phi  \
# 0                 46.062                    1.24                  -2.475
# 1               -999.000                 -999.00                -999.000
# 2               -999.000                 -999.00                -999.000
# 3               -999.000                 -999.00                -999.000
# 4               -999.000                 -999.00                -999.000
#
#    PRI_jet_all_pt
# 0         113.497
# 1          46.226
# 2          44.251
# 3           0.000
# 4           0.000
#
# [5 rows x 31 columns]

# %%
X = df.drop(columns=['Prediction'])
y = df['Prediction']

# %%
y.value_counts()
# Out:
# Prediction
# b    164333
# s     85667
# Name: count, dtype: int64

# %% [markdown]
# we can see the class unbalance !!

# %%
X.value_counts()
# Out:
# DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt  DER_pt_ratio_lep_tau  DER_met_phi_centrality  DER_lep_eta_centrality  PRI_tau_pt  PRI_tau_eta  PRI_tau_phi  PRI_lep_pt  PRI_lep_eta  PRI_lep_phi  PRI_met  PRI_met_phi  PRI_met_sumet  PRI_jet_num  PRI_jet_leading_pt  PRI_jet_leading_eta  PRI_jet_leading_phi  PRI_jet_subleading_pt  PRI_jet_subleading_eta  PRI_jet_subleading_phi  PRI_jet_all_pt
#  925.471      94.656                       193.332       201.953   -999.000              -999.000          -999.000             4.000               2.891       275.461     0.610                  1.400                  -999.000                47.446       1.596        2.852       28.951      -1.654        0.520       167.897   2.013       282.111        1             199.064            -1.685               -1.097               -999.000               -999.000                -999.000                199.064           1
#  923.613      74.368                       220.110       101.685    0.150                 119.315           0.115               4.671               61.188      278.335     0.744                  1.414                   0.000                  39.664      -1.787       -2.673       29.498       1.888        0.726       90.937    2.328       364.976        3             88.040             -0.422               -1.905                85.038                -0.272                  -0.471                  209.173           1
#  922.659      94.717                       649.300       100.773   -999.000              -999.000          -999.000             5.208               3.931       271.982     3.774                  1.402                  -999.000                36.148       2.353       -2.108       136.440     -2.073        1.431       23.863   -2.894       325.596        1             99.393             -2.763               -1.382               -999.000               -999.000                -999.000                99.393            1
#  921.419      76.213                       658.096       82.588     0.357                 107.516          -0.032               4.652               40.010      350.069     0.558                 -1.254                   0.000                  142.127     -2.182       -1.131       79.250       1.414        2.202       18.357   -0.853       352.956        2             88.369              0.195                2.865                40.323                -0.162                   0.756                  128.692           1
#  917.126      18.791                       294.871       113.195    0.626                 39.749            4.346               3.070               26.880      482.485     0.140                  0.261                   0.000                  325.753     -0.392       -0.188       45.731       0.915        2.589       356.198   2.737       624.515        2             78.140              1.795               -1.384                32.860                 2.421                  -1.400                  111.000           1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ..
# -999.000      24.500                       194.886       3.805     -999.000              -999.000          -999.000             2.926               3.805       276.703     0.162                 -1.100                  -999.000                238.128     -0.200        0.636       38.575      -0.640       -2.755       202.046  -2.476       333.616        0            -999.000            -999.000             -999.000             -999.000               -999.000                -999.000                0.000             1
#               17.303                       30.090        469.589    1.743                 434.888           2.404               0.433               43.518      712.293     0.589                  0.209                   0.001                  89.760      -0.890        1.410       52.862      -0.458        1.444       327.588   1.312       693.494        3             414.963             0.907               -2.063                88.072                 2.650                  -0.909                  569.672           1
#               13.178                       747.370       129.832   -999.000              -999.000          -999.000             3.673               31.277      606.686     0.380                  1.217                  -999.000                347.655      0.493        2.409       132.098     -1.824       -1.025       138.439  -1.122       694.822        1             126.933            -1.693                0.282               -999.000               -999.000                -999.000                126.933           1
#               11.998                       97.705        580.134   -999.000              -999.000          -999.000             0.435               2.379       1028.251    1.033                  0.104                  -999.000                219.272     -0.565       -2.897       226.543     -0.130       -2.886       134.609  -2.818       1100.861       1             582.435            -0.261                0.266               -999.000               -999.000                -999.000                582.435           1
#               11.960                       215.735       35.060    -999.000              -999.000          -999.000             2.937               35.060      211.748     0.525                 -0.016                  -999.000                138.862     -1.217       -0.025       72.886      -2.031       -2.848       75.339   -3.009       264.066        0            -999.000            -999.000             -999.000             -999.000               -999.000                -999.000                0.000             1
# Name: count, Length: 250000, dtype: int64

# %% [markdown]
# -999.0 is actually missing values so let's deal with  those first

# %%
import numpy as np
import pandas as pd

X.replace(-999.0, np.nan, inplace=True)

# %%
len(df['DER_mass_MMC']),len(df['DER_mass_transverse_met_lep'])
# Out:
# (250000, 250000)

# %%
for col in X.columns:
    if X[col].isnull().sum() > 0:
        print(f"Column '{col}' has {round((X[col].isnull().sum()/250000)*100)}% missing values.")
    else:
        print(f"Column '{col}' has no missing values.")
# Out:
# Column 'DER_mass_MMC' has 15% missing values.
# Column 'DER_mass_transverse_met_lep' has no missing values.
# Column 'DER_mass_vis' has no missing values.
# Column 'DER_pt_h' has no missing values.
# Column 'DER_deltaeta_jet_jet' has 71% missing values.
# Column 'DER_mass_jet_jet' has 71% missing values.
# Column 'DER_prodeta_jet_jet' has 71% missing values.
# Column 'DER_deltar_tau_lep' has no missing values.
# Column 'DER_pt_tot' has no missing values.
# Column 'DER_sum_pt' has no missing values.
# Column 'DER_pt_ratio_lep_tau' has no missing values.
# Column 'DER_met_phi_centrality' has no missing values.
# Column 'DER_lep_eta_centrality' has 71% missing values.
# Column 'PRI_tau_pt' has no missing values.
# Column 'PRI_tau_eta' has no missing values.
# Column 'PRI_tau_phi' has no missing values.
# Column 'PRI_lep_pt' has no missing values.
# Column 'PRI_lep_eta' has no missing values.
# Column 'PRI_lep_phi' has no missing values.
# Column 'PRI_met' has no missing values.
# Column 'PRI_met_phi' has no missing values.
# Column 'PRI_met_sumet' has no missing values.
# Column 'PRI_jet_num' has no missing values.
# Column 'PRI_jet_leading_pt' has 40% missing values.
# Column 'PRI_jet_leading_eta' has 40% missing values.
# Column 'PRI_jet_leading_phi' has 40% missing values.
# Column 'PRI_jet_subleading_pt' has 71% missing values.
# Column 'PRI_jet_subleading_eta' has 71% missing values.
# Column 'PRI_jet_subleading_phi' has 71% missing values.
# Column 'PRI_jet_all_pt' has no missing values.

# %% [markdown]
# Features with missing > 40% has to be dropped.
#
# ---

# %% [markdown]
# DER_deltaeta_jet_jet,
#
# DER_mass_jet_jet,
#
# DER_prodeta_jet_jet,
#
# DER_lep_eta_centrality,
#
# PRI_jet_subleading_pt,
#
# PRI_jet_subleading_eta,
#
# PRI_jet_subleading_phi
#
# 'PRI_jet_leading_phi',
#
# 'PRI_jet_leading_eta',
#
# 'PRI_jet_leading_pt'

# %%
X.drop(columns=['DER_deltaeta_jet_jet',
'DER_mass_jet_jet',
'DER_prodeta_jet_jet',
'DER_lep_eta_centrality',
'PRI_jet_subleading_pt',
'PRI_jet_subleading_eta',
'PRI_jet_subleading_phi'],inplace=True)

# %%
X.drop(columns=['PRI_jet_leading_phi',
                'PRI_jet_leading_eta',
                'PRI_jet_leading_pt'],inplace=True)

# %%
X.isnull().sum()
# Out:
# DER_mass_MMC                   38114
# DER_mass_transverse_met_lep        0
# DER_mass_vis                       0
# DER_pt_h                           0
# DER_deltar_tau_lep                 0
# DER_pt_tot                         0
# DER_sum_pt                         0
# DER_pt_ratio_lep_tau               0
# DER_met_phi_centrality             0
# PRI_tau_pt                         0
# PRI_tau_eta                        0
# PRI_tau_phi                        0
# PRI_lep_pt                         0
# PRI_lep_eta                        0
# PRI_lep_phi                        0
# PRI_met                            0
# PRI_met_phi                        0
# PRI_met_sumet                      0
# PRI_jet_num                        0
# PRI_jet_all_pt                     0
# dtype: int64

# %% [markdown]
# Imputing with median

# %%
# Median imputation
X['DER_mass_MMC'] = X['DER_mass_MMC'].fillna(X['DER_mass_MMC'].median())

# %%
X.isnull().sum()
# Out:
# DER_mass_MMC                   0
# DER_mass_transverse_met_lep    0
# DER_mass_vis                   0
# DER_pt_h                       0
# DER_deltar_tau_lep             0
# DER_pt_tot                     0
# DER_sum_pt                     0
# DER_pt_ratio_lep_tau           0
# DER_met_phi_centrality         0
# PRI_tau_pt                     0
# PRI_tau_eta                    0
# PRI_tau_phi                    0
# PRI_lep_pt                     0
# PRI_lep_eta                    0
# PRI_lep_phi                    0
# PRI_met                        0
# PRI_met_phi                    0
# PRI_met_sumet                  0
# PRI_jet_num                    0
# PRI_jet_all_pt                 0
# dtype: int64

# %%
import matplotlib.pyplot as plt

X.hist(figsize=(15, 10), bins=50)
plt.suptitle("Feature Distributions", fontsize=16)
plt.show()

# %%
y = df['Prediction']

# %% [markdown]
# Encoding

# %%
label_map = {'b': 0, 's': 1}
y = df['Prediction'].map(label_map)

# %%
display(y.head())
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Prediction, dtype: int64

# %% [markdown]
# Let's Normalise !

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %% [markdown]
# Let's first do ensembling techniques (Bagging)

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y , random_state=42)

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = model.predict(X_test)

# %%
print(classification_report(y_pred=y_pred,y_true=y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.90      0.88     49300
#            1       0.78      0.70      0.74     25700
#
#     accuracy                           0.83     75000
#    macro avg       0.82      0.80      0.81     75000
# weighted avg       0.83      0.83      0.83     75000

# %% [markdown]
# # let's now try Multilayer perceptrons

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input , BatchNormalization
from tensorflow.keras.optimizers import SGD, Adam

# %%
X_train.shape
# Out:
# (175000, 20)

# %%
dl_model = Sequential([
    Input(shape=(X_train.shape[1],)),
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(1, activation='sigmoid')
])
dl_model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
history_dl_model = dl_model.fit(X_train, y_train, epochs=30, batch_size=32, validation_split=0.2,verbose=1)
# Out:
# Epoch 1/30
# 4375/4375 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - accuracy: 0.8061 - loss: 0.4200 - val_accuracy: 0.8277 - val_loss: 0.3797
# Epoch 2/30
# 4375/4375 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - accuracy: 0.8286 - loss: 0.3817 - val_accuracy: 0.8298 - val_loss: 0.3779
# Epoch 3/30
# 4375/4375 ━━━━━━━━━━━━━━━━━━━━ 23s 5ms/step - accuracy: 0.8305 - loss: 0.3770 - val_accuracy: 0.8302 - val_loss: 0.3733
# Epoch 4/30
# 4375/4375 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - accuracy: 0.8310 - loss: 0.3747 - val_accuracy: 0.8302 - val_loss: 0.3723
# Epoch 5/30
# 4375/4375 ━━━━━━━━━━━━━━━━━━━━ 41s 5ms/step - accuracy: 0.8333 - loss: 0.3703 - val_accuracy: 0.8311 - val_loss: 0.3739
# Epoch 6/30
# 4375/4375 ━━━━━━━━━━━━━━━━━━━━ 39s 4ms/step - accuracy: 0.8336 - loss: 0.3684 - val_accuracy: 0.8341 - val_loss: 0.3694
# Epoch 7/30
# 4375/4375 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - accuracy: 0.8342 - loss: 0.3646 - val_accuracy: 0.8323 - val_loss: 0.3716
# Epoch 8/30
# 4375/4375 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - accuracy: 0.8354 - loss: 0.3641 - val_accuracy: 0.8326 - val_loss: 0.3683
# Epoch 9/30
# 4375/4375 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - accuracy: 0.8379 - loss: 0.3605 - val_accuracy: 0.8326 - val_loss: 0.3697
# Epoch 10/30
# 4375/4375 ━━━━━━━━━━━━━━━━━━━━ 19s 4ms/step - accuracy: 0.8385 - loss: 0.3597 - val_accuracy: 0.8342 - val_loss: 0.3692
# Epoch 11/30
# 4375/4375 ━━━━━━━━━━━━━━━━━━━━ 23s 5ms/step - accuracy: 0.8373 - loss: 0.3606 - val_accuracy: 0.8309 - val_loss: 0.3710
# Epoch 12/30
# 4375/4375 ━━━━━━━━━━━━━━━━━━━━ 39s 5ms/step - accuracy: 0.8365 - loss: 0.3599 - val_accuracy: 0.8322 - val_loss: 0.3703
# Epoch 13/30
# 4375/4375 ━━━━━━━━━━━━━━━━━━━━ 43s 5ms/step - accuracy: 0.8383 - loss: 0.3570 - val_accuracy: 0.8323 - val_loss: 0.3698
# Epoch 14/30
# 4375/4375 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - accuracy: 0.8401 - loss: 0.3555 - val_accuracy: 0.8336 - val_loss: 0.3718
# Epoch 15/30
# 4375/4375 ━━━━━━━━━━━━━━━━━━━━ 24s 5ms/step - accuracy: 0.8405 - loss: 0.3548 - val_accuracy: 0.8330 - val_loss: 0.3717
# Epoch 16/30
# 4375/4375 ━━━━━━━━━━━━━━━━━━━━ 24s 6ms/step - accuracy: 0.8407 - loss: 0.3520 - val_accuracy: 0.8347 - val_loss: 0.3732
# Epoch 17/30
# 4375/4375 ━━━━━━━━━━━━━━━━━━━━ 22s 5ms/step - accuracy: 0.8423 - loss: 0.3494 - val_accuracy: 0.8325 - val_loss: 0.3753
# Epoch 18/30
# 4375/4375 ━━━━━━━━━━━━━━━━━━━━ 40s 5ms/step - accuracy: 0.8435 - loss: 0.3481 - val_accuracy: 0.8323 - val_loss: 0.3769
# Epoch 19/30
# 4375/4375 ━━━━━━━━━━━━━━━━━━━━ 39s 4ms/step - accuracy: 0.8434 - loss: 0.3459 - val_accuracy: 0.8330 - val_loss: 0.3761
# Epoch 20/30
# 4375/4375 ━━━━━━━━━━━━━━━━━━━━ 22s 5ms/step - accuracy: 0.8450 - loss: 0.3442 - val_accuracy: 0.8321 - val_loss: 0.3759
# Epoch 21/30
# 4375/4375 ━━━━━━━━━━━━━━━━━━━━ 40s 5ms/step - accuracy: 0.8442 - loss: 0.3450 - val_accuracy: 0.8305 - val_loss: 0.3797
# Epoch 22/30
# 4375/4375 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - accuracy: 0.8470 - loss: 0.3410 - val_accuracy: 0.8297 - val_loss: 0.3843
# Epoch 23/30
# 4375/4375 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - accuracy: 0.8488 - loss: 0.3360 - val_accuracy: 0.8301 - val_loss: 0.3823
# Epoch 24/30
# 4375/4375 ━━━━━━━━━━━━━━━━━━━━ 39s 4ms/step - accuracy: 0.8494 - loss: 0.3356 - val_accuracy: 0.8303 - val_loss: 0.3849
# Epoch 25/30
# 4375/4375 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - accuracy: 0.8487 - loss: 0.3353 - val_accuracy: 0.8304 - val_loss: 0.3850
# Epoch 26/30
# 4375/4375 ━━━━━━━━━━━━━━━━━━━━ 21s 5ms/step - accuracy: 0.8494 - loss: 0.3333 - val_accuracy: 0.8273 - val_loss: 0.3899
# Epoch 27/30
# 4375/4375 ━━━━━━━━━━━━━━━━━━━━ 41s 5ms/step - accuracy: 0.8523 - loss: 0.3285 - val_accuracy: 0.8296 - val_loss: 0.3878
# Epoch 28/30
# 4375/4375 ━━━━━━━━━━━━━━━━━━━━ 45s 6ms/step - accuracy: 0.8512 - loss: 0.3312 - val_accuracy: 0.8279 - val_loss: 0.3935
# Epoch 29/30
# 4375/4375 ━━━━━━━━━━━━━━━━━━━━ 24s 5ms/step - accuracy: 0.8532 - loss: 0.3266 - val_accuracy: 0.8268 - val_loss: 0.3954
# Epoch 30/30
# 4375/4375 ━━━━━━━━━━━━━━━━━━━━ 39s 5ms/step - accuracy: 0.8542 - loss: 0.3245 - val_accuracy: 0.8283 - val_loss: 0.3992

# %%
import matplotlib.pyplot as plt

def plot_learning_curves(history, title='Model'):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(len(acc))  # start at 0

    plt.figure(figsize=(12, 5))

    # Accuracy plot
    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'b-', label='Train Accuracy')
    plt.plot(epochs, val_acc, 'r--', label='Val Accuracy')
    plt.title(f'{title} - Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.xlim(0, len(acc) - 1)
    plt.legend()
    plt.grid(True)

    # Loss plot
    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'b-', label='Train Loss')
    plt.plot(epochs, val_loss, 'r--', label='Val Loss')
    plt.title(f'{title} - Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.xlim(0, len(loss) - 1)
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

# %%
plot_learning_curves(history_dl_model, title='Baseline Model')

# %% [markdown]
# overfitting !

# %%
prediction = dl_model.evaluate(X_test,y_test)
# Out:
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.8260 - loss: 0.4102
# [0.40333741903305054, 0.8269466757774353]

# %%
loss1, acc1 = dl_model.evaluate(X_test, y_test)
print(f"Test accuracy : {100*acc1:.2f}%")
print(f"Test loss     : {100*loss1:.2f}%")
# Out:
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.8260 - loss: 0.4102
# Test accuracy : 82.69%
# Test loss     : 40.33%

# %%
from tensorflow.keras import models, layers

# %%
 model_2 = models.Sequential([
        layers.Input(shape=(X_train.shape[1],)),

        layers.Dense(1024),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Dropout(0.5),

        layers.Dense(512),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Dropout(0.5),

        layers.Dense(256),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Dropout(0.4),

        layers.Dense(128),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Dropout(0.3),

        layers.Dense(64),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Dropout(0.2),

        layers.Dense(1, activation='sigmoid')
    ])

# %%
model_2.compile(optimizer=Adam(learning_rate=0.01),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

# %%
model_2_history = model_2.fit(X_train, y_train,
                                      validation_split=0.2,
                                      epochs=20,
                                      batch_size=256,
                                      verbose=1)
# Out:
# Epoch 1/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 35s 63ms/step - accuracy: 0.8137 - loss: 0.4120 - val_accuracy: 0.8285 - val_loss: 0.3820
# Epoch 2/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 36s 66ms/step - accuracy: 0.8177 - loss: 0.4021 - val_accuracy: 0.8281 - val_loss: 0.3754
# Epoch 3/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 38s 70ms/step - accuracy: 0.8192 - loss: 0.3984 - val_accuracy: 0.8281 - val_loss: 0.3775
# Epoch 4/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 38s 65ms/step - accuracy: 0.8223 - loss: 0.3952 - val_accuracy: 0.8307 - val_loss: 0.3723
# Epoch 5/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 41s 66ms/step - accuracy: 0.8223 - loss: 0.3951 - val_accuracy: 0.8323 - val_loss: 0.3712
# Epoch 6/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 40s 63ms/step - accuracy: 0.8240 - loss: 0.3920 - val_accuracy: 0.8308 - val_loss: 0.3717
# Epoch 7/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 42s 64ms/step - accuracy: 0.8256 - loss: 0.3900 - val_accuracy: 0.8294 - val_loss: 0.3738
# Epoch 8/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 39s 62ms/step - accuracy: 0.8236 - loss: 0.3894 - val_accuracy: 0.8320 - val_loss: 0.3714
# Epoch 9/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 42s 63ms/step - accuracy: 0.8262 - loss: 0.3861 - val_accuracy: 0.8322 - val_loss: 0.3711
# Epoch 10/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 34s 62ms/step - accuracy: 0.8248 - loss: 0.3865 - val_accuracy: 0.8333 - val_loss: 0.3695
# Epoch 11/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 42s 64ms/step - accuracy: 0.8258 - loss: 0.3874 - val_accuracy: 0.8325 - val_loss: 0.3682
# Epoch 12/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 41s 65ms/step - accuracy: 0.8266 - loss: 0.3844 - val_accuracy: 0.8333 - val_loss: 0.3681
# Epoch 13/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 36s 65ms/step - accuracy: 0.8288 - loss: 0.3815 - val_accuracy: 0.8346 - val_loss: 0.3674
# Epoch 14/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 42s 68ms/step - accuracy: 0.8260 - loss: 0.3847 - val_accuracy: 0.8347 - val_loss: 0.3671
# Epoch 15/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 40s 65ms/step - accuracy: 0.8252 - loss: 0.3875 - val_accuracy: 0.8339 - val_loss: 0.3696
# Epoch 16/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 41s 65ms/step - accuracy: 0.8258 - loss: 0.3851 - val_accuracy: 0.8345 - val_loss: 0.3674
# Epoch 17/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 40s 63ms/step - accuracy: 0.8284 - loss: 0.3827 - val_accuracy: 0.8331 - val_loss: 0.3665
# Epoch 18/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 43s 68ms/step - accuracy: 0.8268 - loss: 0.3843 - val_accuracy: 0.8327 - val_loss: 0.3668
# Epoch 19/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 40s 65ms/step - accuracy: 0.8300 - loss: 0.3800 - val_accuracy: 0.8347 - val_loss: 0.3658
# Epoch 20/20
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 40s 63ms/step - accuracy: 0.8285 - loss: 0.3789 - val_accuracy: 0.8348 - val_loss: 0.3663

# %%
plot_learning_curves(model_2_history, title='Model')

# %%
loss1, acc1 = model_2.evaluate(X_test, y_test)
print(f"Test accuracy : {100*acc1:.2f}%")
print(f"Test loss     : {100*loss1:.2f}%")
# Out:
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 17s 7ms/step - accuracy: 0.8325 - loss: 0.3739
# Test accuracy : 83.30%
# Test loss     : 37.10%

# %% [markdown]
# What helped mitigate overfitting?
#
# Ans: Batch Normalisation and Dropout really helped with overfitting.

# %% [markdown]
# Let's see how Different optimizers work

# %%
from tensorflow.keras.optimizers import SGD, Adam, RMSprop, Adagrad, Adadelta, Adamax, Nadam

# %%
 model_3 = models.Sequential([
        layers.Input(shape=(X_train.shape[1],)),

        layers.Dense(1024),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Dropout(0.5),

        layers.Dense(512),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Dropout(0.5),

        layers.Dense(256),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Dropout(0.4),

        layers.Dense(128),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Dropout(0.3),

        layers.Dense(64),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Dropout(0.2),

        layers.Dense(1, activation='sigmoid')
    ])

# %%
model_3.compile(optimizer= RMSprop(learning_rate=0.01),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

# %%
model_3_history = model_2.fit(X_train, y_train,
                                      validation_split=0.2,
                                      epochs=10,
                                      batch_size=256,
                                      verbose=1)
# Out:
# Epoch 1/10
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 34s 63ms/step - accuracy: 0.8317 - loss: 0.3774 - val_accuracy: 0.8361 - val_loss: 0.3643
# Epoch 2/10
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 35s 63ms/step - accuracy: 0.8301 - loss: 0.3746 - val_accuracy: 0.8358 - val_loss: 0.3655
# Epoch 3/10
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 35s 63ms/step - accuracy: 0.8328 - loss: 0.3716 - val_accuracy: 0.8347 - val_loss: 0.3652
# Epoch 4/10
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 41s 64ms/step - accuracy: 0.8332 - loss: 0.3700 - val_accuracy: 0.8336 - val_loss: 0.3658
# Epoch 5/10
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 36s 66ms/step - accuracy: 0.8340 - loss: 0.3721 - val_accuracy: 0.8363 - val_loss: 0.3656
# Epoch 6/10
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 40s 63ms/step - accuracy: 0.8334 - loss: 0.3745 - val_accuracy: 0.8364 - val_loss: 0.3634
# Epoch 7/10
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 41s 64ms/step - accuracy: 0.8310 - loss: 0.3733 - val_accuracy: 0.8353 - val_loss: 0.3638
# Epoch 8/10
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 44s 69ms/step - accuracy: 0.8316 - loss: 0.3737 - val_accuracy: 0.8361 - val_loss: 0.3637
# Epoch 9/10
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 40s 67ms/step - accuracy: 0.8328 - loss: 0.3729 - val_accuracy: 0.8367 - val_loss: 0.3631
# Epoch 10/10
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 41s 68ms/step - accuracy: 0.8302 - loss: 0.3763 - val_accuracy: 0.8370 - val_loss: 0.3625

# %%
plot_learning_curves(model_3_history, title='Model')

# %%
loss1, acc1 =model_3.evaluate(X_test, y_test)
print(f"Test accuracy : {100*acc1:.2f}%")
print(f"Test loss     : {100*loss1:.2f}%")
# Out:
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - accuracy: 0.6587 - loss: 0.6757
# Test accuracy : 65.69%
# Test loss     : 67.58%

# %% [markdown]
# Q :How did the learning rate and optimizer affect convergence?
#
# Ans: convergence with RMSprop did not went well .

# %% [markdown]
# Let's Set callbacks

# %%
 model_4 = models.Sequential([
        layers.Input(shape=(X_train.shape[1],)),

        layers.Dense(1024),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Dropout(0.5),

        layers.Dense(512),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Dropout(0.5),

        layers.Dense(256),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Dropout(0.4),

        layers.Dense(128),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Dropout(0.3),

        layers.Dense(64),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Dropout(0.2),

        layers.Dense(1, activation='sigmoid')
    ])

# %%
model_4.compile(optimizer= Adam(learning_rate=0.1),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

# %% [markdown]
# Changing Learning rate and Defining callbacks

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1, min_lr=1e-6)
checkpoint = ModelCheckpoint('best_classifier.keras', monitor='val_loss', save_best_only=True, verbose=1)
early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True, verbose=1)

# %%
model_4_history = model_4.fit(X_train, y_train,
                                      validation_split=0.2,
                                      epochs=10,
                                      callbacks=[reduce_lr, checkpoint, early_stop],
                                      batch_size=256,
                                      verbose=1)
# Out:
# Epoch 1/10
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7661 - loss: 0.4942
# Epoch 1: val_loss improved from inf to 0.40430, saving model to best_classifier.keras
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 44s 69ms/step - accuracy: 0.7662 - loss: 0.4941 - val_accuracy: 0.8239 - val_loss: 0.4043 - learning_rate: 0.1000
# Epoch 2/10
# 546/547 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8113 - loss: 0.4253
# Epoch 2: val_loss improved from 0.40430 to 0.39436, saving model to best_classifier.keras
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 40s 68ms/step - accuracy: 0.8113 - loss: 0.4253 - val_accuracy: 0.8263 - val_loss: 0.3944 - learning_rate: 0.1000
# Epoch 3/10
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8125 - loss: 0.4207
# Epoch 3: val_loss did not improve from 0.39436
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 40s 66ms/step - accuracy: 0.8125 - loss: 0.4207 - val_accuracy: 0.8177 - val_loss: 0.4017 - learning_rate: 0.1000
# Epoch 4/10
# 546/547 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8156 - loss: 0.4153
# Epoch 4: val_loss improved from 0.39436 to 0.38213, saving model to best_classifier.keras
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 41s 66ms/step - accuracy: 0.8156 - loss: 0.4153 - val_accuracy: 0.8288 - val_loss: 0.3821 - learning_rate: 0.1000
# Epoch 5/10
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8181 - loss: 0.4101
# Epoch 5: val_loss did not improve from 0.38213
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 36s 66ms/step - accuracy: 0.8181 - loss: 0.4101 - val_accuracy: 0.8266 - val_loss: 0.3834 - learning_rate: 0.1000
# Epoch 6/10
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8204 - loss: 0.4086
# Epoch 6: val_loss did not improve from 0.38213
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 42s 68ms/step - accuracy: 0.8204 - loss: 0.4086 - val_accuracy: 0.8279 - val_loss: 0.3874 - learning_rate: 0.1000
# Epoch 7/10
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8206 - loss: 0.4100
# Epoch 7: val_loss improved from 0.38213 to 0.37976, saving model to best_classifier.keras
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 38s 63ms/step - accuracy: 0.8206 - loss: 0.4100 - val_accuracy: 0.8312 - val_loss: 0.3798 - learning_rate: 0.1000
# Epoch 8/10
# 546/547 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8182 - loss: 0.4064
# Epoch 8: val_loss did not improve from 0.37976
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 44s 69ms/step - accuracy: 0.8182 - loss: 0.4064 - val_accuracy: 0.8290 - val_loss: 0.3817 - learning_rate: 0.1000
# Epoch 9/10
# 546/547 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8233 - loss: 0.4011
# Epoch 9: val_loss improved from 0.37976 to 0.37670, saving model to best_classifier.keras
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 40s 68ms/step - accuracy: 0.8233 - loss: 0.4011 - val_accuracy: 0.8297 - val_loss: 0.3767 - learning_rate: 0.1000
# Epoch 10/10
# 546/547 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8209 - loss: 0.4032
# Epoch 10: val_loss improved from 0.37670 to 0.37400, saving model to best_classifier.keras
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 41s 69ms/step - accuracy: 0.8209 - loss: 0.4032 - val_accuracy: 0.8312 - val_loss: 0.3740 - learning_rate: 0.1000
# Restoring model weights from the end of the best epoch: 10.

# %%
loss1, acc1 =model_4.evaluate(X_test, y_test)
print(f"Test accuracy : {100*acc1:.2f}%")
print(f"Test loss     : {100*loss1:.2f}%")
# Out:
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - accuracy: 0.8309 - loss: 0.3808
# Test accuracy : 83.02%
# Test loss     : 37.82%

# %%
plot_learning_curves(model_4_history, title='Model')

# %%
from sklearn.metrics import roc_curve, auc

# %%
y_pred_prob = model_4.predict(X_test)
# Out:
# 2344/2344 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)

# %%
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')  # random baseline
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()
